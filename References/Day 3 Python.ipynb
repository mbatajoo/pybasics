# %%
# Day 3
Problem: Determine frequency of words for given paragraph.
Uses:
    -Dictionary
    -List
    -String Functions
    -While Loop
    -If condition
# Out:
#   File "<ipython-input-3-703f61bcac2d>", line 2
#     Problem: Determine frequency of words for given paragraph.
#                                ^
# SyntaxError: invalid syntax

# %%
paragraph = """My father, a wise and grave man, gave me serious and excellent counsel
against what he foresaw was my design.  He called me one morning into his
chamber, where he was confined by the gout, and expostulated very warmly
with me upon this subject.  He asked me what reasons, more than a mere
wandering inclination, I had for leaving father’s house and my native
country, where I might be well introduced, and had a prospect of raising
my fortune by application and industry, with a life of ease and pleasure.
He told me it was men of desperate fortunes on one hand, or of aspiring,
superior fortunes on the other, who went abroad upon adventures, to rise
by enterprise, and make themselves famous in undertakings of a nature out
of the common road; that these things were all either too far above me or
too far below me; that mine was the middle state, or what might be called
the upper station of low life, which he had found, by long experience,
was the best state in the world, the most suited to human happiness, not
exposed to the miseries and hardships, the labour and sufferings of the
mechanic part of mankind, and not embarrassed with the pride, luxury,
ambition, and envy of the upper part of mankind.  He told me I might
judge of the happiness of this state by this one thing—viz. that this was
the state of life which all other people envied; that kings have
frequently lamented the miserable consequence of being born to great
things, and wished they had been placed in the middle of the two
extremes, between the mean and the great; that the wise man gave his
testimony to this, as the standard of felicity, when he prayed to have
neither poverty nor riches."""

# %%
words=paragraph.split()

# %%
words
# Out:
# ['My',
#  'father,',
#  'a',
#  'wise',
#  'and',
#  'grave',
#  'man,',
#  'gave',
#  'me',
#  'serious',
#  'and',
#  'excellent',
#  'counsel',
#  'against',
#  'what',
#  'he',
#  'foresaw',
#  'was',
#  'my',
#  'design.',
#  'He',
#  'called',
#  'me',
#  'one',
#  'morning',
#  'into',
#  'his',
#  'chamber,',
#  'where',
#  'he',
#  'was',
#  'confined',
#  'by',
#  'the',
#  'gout,',
#  'and',
#  'expostulated',
#  'very',
#  'warmly',
#  'with',
#  'me',
#  'upon',
#  'this',
#  'subject.',
#  'He',
#  'asked',
#  'me',
#  'what',
#  'reasons,',
#  'more',
#  'than',
#  'a',
#  'mere',
#  'wandering',
#  'inclination,',
#  'I',
#  'had',
#  'for',
#  'leaving',
#  'father’s',
#  'house',
#  'and',
#  'my',
#  'native',
#  'country,',
#  'where',
#  'I',
#  'might',
#  'be',
#  'well',
#  'introduced,',
#  'and',
#  'had',
#  'a',
#  'prospect',
#  'of',
#  'raising',
#  'my',
#  'fortune',
#  'by',
#  'application',
#  'and',
#  'industry,',
#  'with',
#  'a',
#  'life',
#  'of',
#  'ease',
#  'and',
#  'pleasure.',
#  'He',
#  'told',
#  'me',
#  'it',
#  'was',
#  'men',
#  'of',
#  'desperate',
#  'fortunes',
#  'on',
#  'one',
#  'hand,',
#  'or',
#  'of',
#  'aspiring,',
#  'superior',
#  'fortunes',
#  'on',
#  'the',
#  'other,',
#  'who',
#  'went',
#  'abroad',
#  'upon',
#  'adventures,',
#  'to',
#  'rise',
#  'by',
#  'enterprise,',
#  'and',
#  'make',
#  'themselves',
#  'famous',
#  'in',
#  'undertakings',
#  'of',
#  'a',
#  'nature',
#  'out',
#  'of',
#  'the',
#  'common',
#  'road;',
#  'that',
#  'these',
#  'things',
#  'were',
#  'all',
#  'either',
#  'too',
#  'far',
#  'above',
#  'me',
#  'or',
#  'too',
#  'far',
#  'below',
#  'me;',
#  'that',
#  'mine',
#  'was',
#  'the',
#  'middle',
#  'state,',
#  'or',
#  'what',
#  'might',
#  'be',
#  'called',
#  'the',
#  'upper',
#  'station',
#  'of',
#  'low',
#  'life,',
#  'which',
#  'he',
#  'had',
#  'found,',
#  'by',
#  'long',
#  'experience,',
#  'was',
#  'the',
#  'best',
#  'state',
#  'in',
#  'the',
#  'world,',
#  'the',
#  'most',
#  'suited',
#  'to',
#  'human',
#  'happiness,',
#  'not',
#  'exposed',
#  'to',
#  'the',
#  'miseries',
#  'and',
#  'hardships,',
#  'the',
#  'labour',
#  'and',
#  'sufferings',
#  'of',
#  'the',
#  'mechanic',
#  'part',
#  'of',
#  'mankind,',
#  'and',
#  'not',
#  'embarrassed',
#  'with',
#  'the',
#  'pride,',
#  'luxury,',
#  'ambition,',
#  'and',
#  'envy',
#  'of',
#  'the',
#  'upper',
#  'part',
#  'of',
#  'mankind.',
#  'He',
#  'told',
#  'me',
#  'I',
#  'might',
#  'judge',
#  'of',
#  'the',
#  'happiness',
#  'of',
#  'this',
#  'state',
#  'by',
#  'this',
#  'one',
#  'thing—viz.',
#  'that',
#  'this',
#  'was',
#  'the',
#  'state',
#  'of',
#  'life',
#  'which',
#  'all',
#  'other',
#  'people',
#  'envied;',
#  'that',
#  'kings',
#  'have',
#  'frequently',
#  'lamented',
#  'the',
#  'miserable',
#  'consequence',
#  'of',
#  'being',
#  'born',
#  'to',
#  'great',
#  'things,',
#  'and',
#  'wished',
#  'they',
#  'had',
#  'been',
#  'placed',
#  'in',
#  'the',
#  'middle',
#  'of',
#  'the',
#  'two',
#  'extremes,',
#  'between',
#  'the',
#  'mean',
#  'and',
#  'the',
#  'great;',
#  'that',
#  'the',
#  'wise',
#  'man',
#  'gave',
#  'his',
#  'testimony',
#  'to',
#  'this,',
#  'as',
#  'the',
#  'standard',
#  'of',
#  'felicity,',
#  'when',
#  'he',
#  'prayed',
#  'to',
#  'have',
#  'neither',
#  'poverty',
#  'nor',
#  'riches.']

# %%
index = 0
while index <len(words):
    print (index, words[index])
    index += 1
print('number of words', len(words))
# Out:
# 0 My
# 1 father,
# 2 a
# 3 wise
# 4 and
# 5 grave
# 6 man,
# 7 gave
# 8 me
# 9 serious
# 10 and
# 11 excellent
# 12 counsel
# 13 against
# 14 what
# 15 he
# 16 foresaw
# 17 was
# 18 my
# 19 design.
# 20 He
# 21 called
# 22 me
# 23 one
# 24 morning
# 25 into
# 26 his
# 27 chamber,
# 28 where
# 29 he
# 30 was
# 31 confined
# 32 by
# 33 the
# 34 gout,
# 35 and
# 36 expostulated
# 37 very
# 38 warmly
# 39 with
# 40 me
# 41 upon
# 42 this
# 43 subject.
# 44 He
# 45 asked
# 46 me
# 47 what
# 48 reasons,
# 49 more
# 50 than
# 51 a
# 52 mere
# 53 wandering
# 54 inclination,
# 55 I
# 56 had
# 57 for
# 58 leaving
# 59 father’s
# 60 house
# 61 and
# 62 my
# 63 native
# 64 country,
# 65 where
# 66 I
# 67 might
# 68 be
# 69 well
# 70 introduced,
# 71 and
# 72 had
# 73 a
# 74 prospect
# 75 of
# 76 raising
# 77 my
# 78 fortune
# 79 by
# 80 application
# 81 and
# 82 industry,
# 83 with
# 84 a
# 85 life
# 86 of
# 87 ease
# 88 and
# 89 pleasure.
# 90 He
# 91 told
# 92 me
# 93 it
# 94 was
# 95 men
# 96 of
# 97 desperate
# 98 fortunes
# 99 on
# 100 one
# 101 hand,
# 102 or
# 103 of
# 104 aspiring,
# 105 superior
# 106 fortunes
# 107 on
# 108 the
# 109 other,
# 110 who
# 111 went
# 112 abroad
# 113 upon
# 114 adventures,
# 115 to
# 116 rise
# 117 by
# 118 enterprise,
# 119 and
# 120 make
# 121 themselves
# 122 famous
# 123 in
# 124 undertakings
# 125 of
# 126 a
# 127 nature
# 128 out
# 129 of
# 130 the
# 131 common
# 132 road;
# 133 that
# 134 these
# 135 things
# 136 were
# 137 all
# 138 either
# 139 too
# 140 far
# 141 above
# 142 me
# 143 or
# 144 too
# 145 far
# 146 below
# 147 me;
# 148 that
# 149 mine
# 150 was
# 151 the
# 152 middle
# 153 state,
# 154 or
# 155 what
# 156 might
# 157 be
# 158 called
# 159 the
# 160 upper
# 161 station
# 162 of
# 163 low
# 164 life,
# 165 which
# 166 he
# 167 had
# 168 found,
# 169 by
# 170 long
# 171 experience,
# 172 was
# 173 the
# 174 best
# 175 state
# 176 in
# 177 the
# 178 world,
# 179 the
# 180 most
# 181 suited
# 182 to
# 183 human
# 184 happiness,
# 185 not
# 186 exposed
# 187 to
# 188 the
# 189 miseries
# 190 and
# 191 hardships,
# 192 the
# 193 labour
# 194 and
# 195 sufferings
# 196 of
# 197 the
# 198 mechanic
# 199 part
# 200 of
# 201 mankind,
# 202 and
# 203 not
# 204 embarrassed
# 205 with
# 206 the
# 207 pride,
# 208 luxury,
# 209 ambition,
# 210 and
# 211 envy
# 212 of
# 213 the
# 214 upper
# 215 part
# 216 of
# 217 mankind.
# 218 He
# 219 told
# 220 me
# 221 I
# 222 might
# 223 judge
# 224 of
# 225 the
# 226 happiness
# 227 of
# 228 this
# 229 state
# 230 by
# 231 this
# 232 one
# 233 thing—viz.
# 234 that
# 235 this
# 236 was
# 237 the
# 238 state
# 239 of
# 240 life
# 241 which
# 242 all
# 243 other
# 244 people
# 245 envied;
# 246 that
# 247 kings
# 248 have
# 249 frequently
# 250 lamented
# 251 the
# 252 miserable
# 253 consequence
# 254 of
# 255 being
# 256 born
# 257 to
# 258 great
# 259 things,
# 260 and
# 261 wished
# 262 they
# 263 had
# 264 been
# 265 placed
# 266 in
# 267 the
# 268 middle
# 269 of
# 270 the
# 271 two
# 272 extremes,
# 273 between
# 274 the
# 275 mean
# 276 and
# 277 the
# 278 great;
# 279 that
# 280 the
# 281 wise
# 282 man
# 283 gave
# 284 his
# 285 testimony
# 286 to
# 287 this,
# 288 as
# 289 the
# 290 standard
# 291 of
# 292 felicity,
# 293 when
# 294 he
# 295 prayed
# 296 to
# 297 have
# 298 neither
# 299 poverty
# 300 nor
# 301 riches.
# number of words 302

# %%
freq = {}
index = 0
while index < len(words):
    word = words[index].strip('.').strip(',').lower()
    #word = words[index]
    #word = word.strip('.')
    #word = word.lower()
    print (word)
    freq[word]=0
    index += 1
print(freq)
# Out:
# my
# father
# a
# wise
# and
# grave
# man
# gave
# me
# serious
# and
# excellent
# counsel
# against
# what
# he
# foresaw
# was
# my
# design
# he
# called
# me
# one
# morning
# into
# his
# chamber
# where
# he
# was
# confined
# by
# the
# gout
# and
# expostulated
# very
# warmly
# with
# me
# upon
# this
# subject
# he
# asked
# me
# what
# reasons
# more
# than
# a
# mere
# wandering
# inclination
# i
# had
# for
# leaving
# father’s
# house
# and
# my
# native
# country
# where
# i
# might
# be
# well
# introduced
# and
# had
# a
# prospect
# of
# raising
# my
# fortune
# by
# application
# and
# industry
# with
# a
# life
# of
# ease
# and
# pleasure
# he
# told
# me
# it
# was
# men
# of
# desperate
# fortunes
# on
# one
# hand
# or
# of
# aspiring
# superior
# fortunes
# on
# the
# other
# who
# went
# abroad
# upon
# adventures
# to
# rise
# by
# enterprise
# and
# make
# themselves
# famous
# in
# undertakings
# of
# a
# nature
# out
# of
# the
# common
# road;
# that
# these
# things
# were
# all
# either
# too
# far
# above
# me
# or
# too
# far
# below
# me;
# that
# mine
# was
# the
# middle
# state
# or
# what
# might
# be
# called
# the
# upper
# station
# of
# low
# life
# which
# he
# had
# found
# by
# long
# experience
# was
# the
# best
# state
# in
# the
# world
# the
# most
# suited
# to
# human
# happiness
# not
# exposed
# to
# the
# miseries
# and
# hardships
# the
# labour
# and
# sufferings
# of
# the
# mechanic
# part
# of
# mankind
# and
# not
# embarrassed
# with
# the
# pride
# luxury
# ambition
# and
# envy
# of
# the
# upper
# part
# of
# mankind
# he
# told
# me
# i
# might
# judge
# of
# the
# happiness
# of
# this
# state
# by
# this
# one
# thing—viz
# that
# this
# was
# the
# state
# of
# life
# which
# all
# other
# people
# envied;
# that
# kings
# have
# frequently
# lamented
# the
# miserable
# consequence
# of
# being
# born
# to
# great
# things
# and
# wished
# they
# had
# been
# placed
# in
# the
# middle
# of
# the
# two
# extremes
# between
# the
# mean
# and
# the
# great;
# that
# the
# wise
# man
# gave
# his
# testimony
# to
# this
# as
# the
# standard
# of
# felicity
# when
# he
# prayed
# to
# have
# neither
# poverty
# nor
# riches
# {'my': 0, 'father': 0, 'a': 0, 'wise': 0, 'and': 0, 'grave': 0, 'man': 0, 'gave': 0, 'me': 0, 'serious': 0, 'excellent': 0, 'counsel': 0, 'against': 0, 'what': 0, 'he': 0, 'foresaw': 0, 'was': 0, 'design': 0, 'called': 0, 'one': 0, 'morning': 0, 'into': 0, 'his': 0, 'chamber': 0, 'where': 0, 'confined': 0, 'by': 0, 'the': 0, 'gout': 0, 'expostulated': 0, 'very': 0, 'warmly': 0, 'with': 0, 'upon': 0, 'this': 0, 'subject': 0, 'asked': 0, 'reasons': 0, 'more': 0, 'than': 0, 'mere': 0, 'wandering': 0, 'inclination': 0, 'i': 0, 'had': 0, 'for': 0, 'leaving': 0, 'father’s': 0, 'house': 0, 'native': 0, 'country': 0, 'might': 0, 'be': 0, 'well': 0, 'introduced': 0, 'prospect': 0, 'of': 0, 'raising': 0, 'fortune': 0, 'application': 0, 'industry': 0, 'life': 0, 'ease': 0, 'pleasure': 0, 'told': 0, 'it': 0, 'men': 0, 'desperate': 0, 'fortunes': 0, 'on': 0, 'hand': 0, 'or': 0, 'aspiring': 0, 'superior': 0, 'other': 0, 'who': 0, 'went': 0, 'abroad': 0, 'adventures': 0, 'to': 0, 'rise': 0, 'enterprise': 0, 'make': 0, 'themselves': 0, 'famous': 0, 'in': 0, 'undertakings': 0, 'nature': 0, 'out': 0, 'common': 0, 'road;': 0, 'that': 0, 'these': 0, 'things': 0, 'were': 0, 'all': 0, 'either': 0, 'too': 0, 'far': 0, 'above': 0, 'below': 0, 'me;': 0, 'mine': 0, 'middle': 0, 'state': 0, 'upper': 0, 'station': 0, 'low': 0, 'which': 0, 'found': 0, 'long': 0, 'experience': 0, 'best': 0, 'world': 0, 'most': 0, 'suited': 0, 'human': 0, 'happiness': 0, 'not': 0, 'exposed': 0, 'miseries': 0, 'hardships': 0, 'labour': 0, 'sufferings': 0, 'mechanic': 0, 'part': 0, 'mankind': 0, 'embarrassed': 0, 'pride': 0, 'luxury': 0, 'ambition': 0, 'envy': 0, 'judge': 0, 'thing—viz': 0, 'people': 0, 'envied;': 0, 'kings': 0, 'have': 0, 'frequently': 0, 'lamented': 0, 'miserable': 0, 'consequence': 0, 'being': 0, 'born': 0, 'great': 0, 'wished': 0, 'they': 0, 'been': 0, 'placed': 0, 'two': 0, 'extremes': 0, 'between': 0, 'mean': 0, 'great;': 0, 'testimony': 0, 'as': 0, 'standard': 0, 'felicity': 0, 'when': 0, 'prayed': 0, 'neither': 0, 'poverty': 0, 'nor': 0, 'riches': 0}

# %%
freq = {}
index = 0
while index < len(words):
    word = words[index].strip('.').strip(',').lower()
    if word in freq:
         freq [word] += 1
    else:
         freq[word]=1
    index += 1
print(freq)
# Out:
# {'my': 4, 'father': 1, 'a': 5, 'wise': 2, 'and': 14, 'grave': 1, 'man': 2, 'gave': 2, 'me': 7, 'serious': 1, 'excellent': 1, 'counsel': 1, 'against': 1, 'what': 3, 'he': 8, 'foresaw': 1, 'was': 6, 'design': 1, 'called': 2, 'one': 3, 'morning': 1, 'into': 1, 'his': 2, 'chamber': 1, 'where': 2, 'confined': 1, 'by': 5, 'the': 22, 'gout': 1, 'expostulated': 1, 'very': 1, 'warmly': 1, 'with': 3, 'upon': 2, 'this': 5, 'subject': 1, 'asked': 1, 'reasons': 1, 'more': 1, 'than': 1, 'mere': 1, 'wandering': 1, 'inclination': 1, 'i': 3, 'had': 4, 'for': 1, 'leaving': 1, 'father’s': 1, 'house': 1, 'native': 1, 'country': 1, 'might': 3, 'be': 2, 'well': 1, 'introduced': 1, 'prospect': 1, 'of': 17, 'raising': 1, 'fortune': 1, 'application': 1, 'industry': 1, 'life': 3, 'ease': 1, 'pleasure': 1, 'told': 2, 'it': 1, 'men': 1, 'desperate': 1, 'fortunes': 2, 'on': 2, 'hand': 1, 'or': 3, 'aspiring': 1, 'superior': 1, 'other': 2, 'who': 1, 'went': 1, 'abroad': 1, 'adventures': 1, 'to': 6, 'rise': 1, 'enterprise': 1, 'make': 1, 'themselves': 1, 'famous': 1, 'in': 3, 'undertakings': 1, 'nature': 1, 'out': 1, 'common': 1, 'road;': 1, 'that': 5, 'these': 1, 'things': 2, 'were': 1, 'all': 2, 'either': 1, 'too': 2, 'far': 2, 'above': 1, 'below': 1, 'me;': 1, 'mine': 1, 'middle': 2, 'state': 4, 'upper': 2, 'station': 1, 'low': 1, 'which': 2, 'found': 1, 'long': 1, 'experience': 1, 'best': 1, 'world': 1, 'most': 1, 'suited': 1, 'human': 1, 'happiness': 2, 'not': 2, 'exposed': 1, 'miseries': 1, 'hardships': 1, 'labour': 1, 'sufferings': 1, 'mechanic': 1, 'part': 2, 'mankind': 2, 'embarrassed': 1, 'pride': 1, 'luxury': 1, 'ambition': 1, 'envy': 1, 'judge': 1, 'thing—viz': 1, 'people': 1, 'envied;': 1, 'kings': 1, 'have': 2, 'frequently': 1, 'lamented': 1, 'miserable': 1, 'consequence': 1, 'being': 1, 'born': 1, 'great': 1, 'wished': 1, 'they': 1, 'been': 1, 'placed': 1, 'two': 1, 'extremes': 1, 'between': 1, 'mean': 1, 'great;': 1, 'testimony': 1, 'as': 1, 'standard': 1, 'felicity': 1, 'when': 1, 'prayed': 1, 'neither': 1, 'poverty': 1, 'nor': 1, 'riches': 1}

# %%
for item in freq:
    print('Pragraph has{}"{}"'.format(freq[item],item ))
# Out:
# Pragraph has4"my"
# Pragraph has1"father"
# Pragraph has5"a"
# Pragraph has2"wise"
# Pragraph has14"and"
# Pragraph has1"grave"
# Pragraph has2"man"
# Pragraph has2"gave"
# Pragraph has7"me"
# Pragraph has1"serious"
# Pragraph has1"excellent"
# Pragraph has1"counsel"
# Pragraph has1"against"
# Pragraph has3"what"
# Pragraph has8"he"
# Pragraph has1"foresaw"
# Pragraph has6"was"
# Pragraph has1"design"
# Pragraph has2"called"
# Pragraph has3"one"
# Pragraph has1"morning"
# Pragraph has1"into"
# Pragraph has2"his"
# Pragraph has1"chamber"
# Pragraph has2"where"
# Pragraph has1"confined"
# Pragraph has5"by"
# Pragraph has22"the"
# Pragraph has1"gout"
# Pragraph has1"expostulated"
# Pragraph has1"very"
# Pragraph has1"warmly"
# Pragraph has3"with"
# Pragraph has2"upon"
# Pragraph has5"this"
# Pragraph has1"subject"
# Pragraph has1"asked"
# Pragraph has1"reasons"
# Pragraph has1"more"
# Pragraph has1"than"
# Pragraph has1"mere"
# Pragraph has1"wandering"
# Pragraph has1"inclination"
# Pragraph has3"i"
# Pragraph has4"had"
# Pragraph has1"for"
# Pragraph has1"leaving"
# Pragraph has1"father’s"
# Pragraph has1"house"
# Pragraph has1"native"
# Pragraph has1"country"
# Pragraph has3"might"
# Pragraph has2"be"
# Pragraph has1"well"
# Pragraph has1"introduced"
# Pragraph has1"prospect"
# Pragraph has17"of"
# Pragraph has1"raising"
# Pragraph has1"fortune"
# Pragraph has1"application"
# Pragraph has1"industry"
# Pragraph has3"life"
# Pragraph has1"ease"
# Pragraph has1"pleasure"
# Pragraph has2"told"
# Pragraph has1"it"
# Pragraph has1"men"
# Pragraph has1"desperate"
# Pragraph has2"fortunes"
# Pragraph has2"on"
# Pragraph has1"hand"
# Pragraph has3"or"
# Pragraph has1"aspiring"
# Pragraph has1"superior"
# Pragraph has2"other"
# Pragraph has1"who"
# Pragraph has1"went"
# Pragraph has1"abroad"
# Pragraph has1"adventures"
# Pragraph has6"to"
# Pragraph has1"rise"
# Pragraph has1"enterprise"
# Pragraph has1"make"
# Pragraph has1"themselves"
# Pragraph has1"famous"
# Pragraph has3"in"
# Pragraph has1"undertakings"
# Pragraph has1"nature"
# Pragraph has1"out"
# Pragraph has1"common"
# Pragraph has1"road;"
# Pragraph has5"that"
# Pragraph has1"these"
# Pragraph has2"things"
# Pragraph has1"were"
# Pragraph has2"all"
# Pragraph has1"either"
# Pragraph has2"too"
# Pragraph has2"far"
# Pragraph has1"above"
# Pragraph has1"below"
# Pragraph has1"me;"
# Pragraph has1"mine"
# Pragraph has2"middle"
# Pragraph has4"state"
# Pragraph has2"upper"
# Pragraph has1"station"
# Pragraph has1"low"
# Pragraph has2"which"
# Pragraph has1"found"
# Pragraph has1"long"
# Pragraph has1"experience"
# Pragraph has1"best"
# Pragraph has1"world"
# Pragraph has1"most"
# Pragraph has1"suited"
# Pragraph has1"human"
# Pragraph has2"happiness"
# Pragraph has2"not"
# Pragraph has1"exposed"
# Pragraph has1"miseries"
# Pragraph has1"hardships"
# Pragraph has1"labour"
# Pragraph has1"sufferings"
# Pragraph has1"mechanic"
# Pragraph has2"part"
# Pragraph has2"mankind"
# Pragraph has1"embarrassed"
# Pragraph has1"pride"
# Pragraph has1"luxury"
# Pragraph has1"ambition"
# Pragraph has1"envy"
# Pragraph has1"judge"
# Pragraph has1"thing—viz"
# Pragraph has1"people"
# Pragraph has1"envied;"
# Pragraph has1"kings"
# Pragraph has2"have"
# Pragraph has1"frequently"
# Pragraph has1"lamented"
# Pragraph has1"miserable"
# Pragraph has1"consequence"
# Pragraph has1"being"
# Pragraph has1"born"
# Pragraph has1"great"
# Pragraph has1"wished"
# Pragraph has1"they"
# Pragraph has1"been"
# Pragraph has1"placed"
# Pragraph has1"two"
# Pragraph has1"extremes"
# Pragraph has1"between"
# Pragraph has1"mean"
# Pragraph has1"great;"
# Pragraph has1"testimony"
# Pragraph has1"as"
# Pragraph has1"standard"
# Pragraph has1"felicity"
# Pragraph has1"when"
# Pragraph has1"prayed"
# Pragraph has1"neither"
# Pragraph has1"poverty"
# Pragraph has1"nor"
# Pragraph has1"riches"
